# %% [markdown]
# Load files and Nilearn functionalities

# %%
import nilearn

# %%
from nilearn.datasets import MNI152_FILE_PATH

# %%
#Print path file
print('Path to MNI152 template: %r' % MNI152_FILE_PATH)
# Out:
# Path to MNI152 template: '/Users/isabellesimard2/anaconda3/lib/python3.7/site-packages/nilearn/datasets/data/avg152T1_brain.nii.gz'

# %% [markdown]
# # Plotting the data

# %%
from nilearn import plotting
plotting.plot_img(MNI152_FILE_PATH)
